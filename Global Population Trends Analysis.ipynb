# %%
df.columns
# Out:
# Index(['Country Name\tCountry Code\tIndicator Name\tIndicator Code\t1960\t1961\t1962\t1963\t1964\t1965\t1966\t1967\t1968\t1969\t1970\t1971\t1972\t1973\t1974\t1975\t1976\t1977\t1978\t1979\t1980\t1981\t1982\t1983\t1984\t1985\t1986\t1987\t1988\t1989\t1990\t1991\t1992\t1993\t1994\t1995\t1996\t1997\t1998\t1999\t2000\t2001\t2002\t2003\t2004\t2005\t2006\t2007\t2008\t2009\t2010\t2011\t2012\t2013\t2014\t2015\t2016\t2017\t2018\t2019\t2020\t2021\t2022\t2023\t2024'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv" ,skiprows=4,engine='python',sep="\t", on_bad_lines="skip")

df.columns = df.columns.str.strip()

print(df.head())
print(df.columns)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Remove extra spaces in column names:
df.columns=df.columns.str.strip()
# Remove rows where country name is missing:
df=df[df['Country Name'].notna()]
#Convert 2023 population to numeric:
df['2023']=pd.to_numeric(df['2023'],errors='coerce')
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_clean=df[['Country Name','2023']].dropna()

# %%
# Keep only Population indicator rows
df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3) &
    (~df['Country Name'].str.contains(
        'income|OECD|UN|classified|situations|members|states|Europe|Asia|Africa',
        case=False,
        na=False
    ))
][['Country Name', '2023']].dropna()
#Top 10 Countries by population:
top10=df_clean.sort_values(by='2023',ascending=False).head(10)
#Plot Bar chart:
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'],top10['2023'])
plt.xticks(rotation=90)
plt.title("Top 10 Countries by Population 2023")
plt.xlabel("Countries")
plt.ylabel("Population")
plt.show()

print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Load World Bank Dataset
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",skiprows=4,engine="python")

# 2️⃣ Clean column names (remove hidden spaces)
df.columns = df.columns.str.strip()

# 3️⃣ Convert 2023 column to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# 4️⃣ Filter only real countries (remove aggregates & regions)
df_countries = df[(df['Indicator Name'] == 'Population, total') & (df['Country Code'].str.len() == 3) & (~df['Country Name'].str.contains('income|OECD|UN|classified|situations|members|states|Europe|Asia|Africa',case=False, na=False))][['Country Name', '2023']].dropna()

# 5️⃣ Get Top 10 countries by population (2023)
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

# 6️⃣ Plot Bar Chart
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])

plt.xticks(rotation=90)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\python_parser.py:805, in PythonParser._next_iter_line(self, row_num)
#     804 assert self.data is not None
# --> 805 line = next(self.data)
#     806 # for mypy
#
# Error: ',' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[21], line 5
#       2 import matplotlib.pyplot as plt
#       4 # 1️⃣ Load World Bank Dataset
# ----> 5 df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",skiprows=4,engine="python")
#       7 # 2️⃣ Clean column names (remove hidden spaces)
#       8 df.columns = df.columns.str.strip()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load correctly
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv"
    ,
    skiprows=4,
    sep="\t"
    encoding="latin1",
    on_bad_lines="skip"
)

df.columns = df.columns.str.strip()
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3)
][['Country Name', 'Country Code', '2023']].dropna()

top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])

plt.xticks(rotation=90)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2023'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 13
# ...

# %%
repr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 repr()
#
# TypeError: repr() takes exactly one argument (0 given)

# %%
print(df.columns.tolist())
# Out:
# ['Country Name\tCountry Code\tIndicator Name\tIndicator Code\t1960\t1961\t1962\t1963\t1964\t1965\t1966\t1967\t1968\t1969\t1970\t1971\t1972\t1973\t1974\t1975\t1976\t1977\t1978\t1979\t1980\t1981\t1982\t1983\t1984\t1985\t1986\t1987\t1988\t1989\t1990\t1991\t1992\t1993\t1994\t1995\t1996\t1997\t1998\t1999\t2000\t2001\t2002\t2003\t2004\t2005\t2006\t2007\t2008\t2009\t2010\t2011\t2012\t2013\t2014\t2015\t2016\t2017\t2018\t2019\t2020\t2021\t2022\t2023\t2024']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Load dataset correctly (TAB separated)
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv"
    ,
    skiprows=4,
    sep="\t"
)

# 2️⃣ Clean column names
df.columns = df.columns.str.strip()

# 3️⃣ Convert 2023 column to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3) &
    (~df['Country Name'].str.contains(
        'income|OECD|UN|classified|situations|members|states|Europe|Asia|Africa|World|dividend',
        case=False,
        na=False
    ))
][['Country Name', '2023']].dropna()

# 6️⃣ Get Top 10 Countries
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

# 7️⃣ Plot Bar Chart
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])

plt.xticks(rotation=90)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv"
   ,
    skiprows=4,
    encoding="latin1",
    on_bad_lines="skip"
)

# Clean column names
df.columns = df.columns.str.strip()

# Convert 2023 to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# Keep only real countries (3-letter codes & no aggregates)
df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3)
][['Country Name', 'Country Code', '2023']].dropna()

# Remove obvious non-country entries
df_countries = df_countries[
    ~df_countries['Country Name'].str.contains(
        'World|income|OECD|UN|Asia|Africa|Europe|IDA|IBRD|dividend',
        case=False,
        na=False
    )
]

# Get top 10 countries
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

# Plot
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])
plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2023'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 16
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Country Name\tCountry Code\tIndicator Name\tIndicator Code\t1960\t1961\t1962\t1963\t1964\t1965\t1966\t1967\t1968\t1969\t1970\t1971\t1972\t1973\t1974\t1975\t1976\t1977\t1978\t1979\t1980\t1981\t1982\t1983\t1984\t1985\t1986\t1987\t1988\t1989\t1990\t1991\t1992\t1993\t1994\t1995\t1996\t1997\t1998\t1999\t2000\t2001\t2002\t2003\t2004\t2005\t2006\t2007\t2008\t2009\t2010\t2011\t2012\t2013\t2014\t2015\t2016\t2017\t2018\t2019\t2020\t2021\t2022\t2023\t2024']

# %%
df.columns = df.columns.str.replace('\t', "")
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Country NameCountry CodeIndicator NameIndicator ']

# %%
# Out:
# ['Country Name\tCountry Code\tIndicator Name\tIndicator Code\t1960\t1961\t1962\t1963\t1964\t1965\t1966\t1967\t1968\t1969\t1970\t1971\t1972\t1973\t1974\t1975\t1976\t1977\t1978\t1979\t1980\t1981\t1982\t1983\t1984\t1985\t1986\t1987\t1988\t1989\t1990\t1991\t1992\t1993\t1994\t1995\t1996\t1997\t1998\t1999\t2000\t2001\t2002\t2003\t2004\t2005\t2006\t2007\t2008\t2009\t2010\t2011\t2012\t2013\t2014\t2015\t2016\t2017\t2018\t2019\t2020\t2021\t2022\t2023\t2024']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
   
    skiprows=4,
    sep='\t',   # IMPORTANT
    engine='python')

df.columns = df.columns.str.strip()

print(df.columns.tolist())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
   
    skiprows=4,
    sep='\t',   # IMPORTANT
    engine='python')

df.columns = df.columns.str.strip()

print(df.columns.tolist())

# Convert 2023 column
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# Keep only rows where:
# 1) Indicator is Population
# 2) Country Code is exactly 3 letters
# 3) No aggregates using Country Code logic

df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3) &
    (~df['Country Code'].isin([
        'WLD','EAS','ECS','EMU','EUU','FCS','HIC','IBD','IBT',
        'IDA','IDX','LDC','LIC','LMC','LMY','MEA','MIC','NAC',
        'OED','OSS','PRE','PST','SAS','SSA','SSF','UMC'
    ]))
][['Country Name', '2023']].dropna()
# Top 10 countries
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])

plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.tight_layout()
plt.show()
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load file (TAB separated)
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
    skiprows=4,
    sep='\t',
    engine='python'
)

# Clean column names
df.columns = df.columns.str.strip()

# Convert 2023 to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# Remove aggregates using Indicator Name AND exclude known groups
df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (~df['Country Name'].str.contains(
        'World|income|Europe|Asia|Africa|Pacific|IDA|IBRD|dividend|OECD|classified',
        case=False,
        na=False
    ))
][['Country Name', 'Country Code', '2023']].dropna()

# Sort
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

print(top10)

# Plot
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])
plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.tight_layout()
plt.show()
# Out:
#                                      Country Name Country Code          2023
# 109                                         India          IND  1.438070e+09
# 40                                          China          CHN  1.410710e+09
# 135  Least developed countries: UN classification          LDC  1.160825e+09
# 74       Fragile and conflict affected situations          FCS  1.058716e+09
# 98         Heavily indebted poor countries (HIPC)          HPC  9.173043e+08
# 134                     Latin America & Caribbean          LCN  6.576177e+08
# 170                                 North America          NAC  3.769544e+08
# 68                                      Euro area          EMU  3.502927e+08
# 251                                 United States          USA  3.368062e+08
# 106                                     Indonesia          IDN  2.811901e+08

# %%
print(top10)
# Out:
#                    Country Name          2023
# 259                       World  8.064977e+09
# 103            IDA & IBRD total  6.858864e+09
# 140         Low & middle income  6.499219e+09
# 156               Middle income  5.891445e+09
# 102                   IBRD only  4.952555e+09
# 62   Early-demographic dividend  3.511608e+09
# 139         Lower middle income  3.082003e+09
# 249         Upper middle income  2.809442e+09
# 63          East Asia & Pacific  2.384479e+09
# 142   Late-demographic dividend  2.326637e+09

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load file (TAB separated)
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
    skiprows=4,
    sep='\t',
    engine='python'
)

# Clean column names
df.columns = df.columns.str.strip()

# Convert 2023 to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# Remove aggregates using Indicator Name AND exclude known groups
df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (~df['Country Name'].str.contains(
        'World|income|Europe|Asia|Africa|Pacific|IDA|IBRD|dividend|OECD|classified',
        case=False,
        na=False
    ))
][['Country Name', 'Country Code', '2023']].dropna()

# Sort
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

print(top10)

# Plot
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])
plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.tight_layout()
plt.show()
# Out:
#                                      Country Name Country Code          2023
# 109                                         India          IND  1.438070e+09
# 40                                          China          CHN  1.410710e+09
# 135  Least developed countries: UN classification          LDC  1.160825e+09
# 74       Fragile and conflict affected situations          FCS  1.058716e+09
# 98         Heavily indebted poor countries (HIPC)          HPC  9.173043e+08
# 134                     Latin America & Caribbean          LCN  6.576177e+08
# 170                                 North America          NAC  3.769544e+08
# 68                                      Euro area          EMU  3.502927e+08
# 251                                 United States          USA  3.368062e+08
# 106                                     Indonesia          IDN  2.811901e+08

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load file (TAB separated)
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
    skiprows=4,
    sep='\t',
    engine='python'
)

# Clean column names
df.columns = df.columns.str.strip()
# Convert 2023 to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

# Remove aggregates using Indicator Name AND exclude known groups
df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (~df['Country Name'].str.contains(
        'World|income|Europe|Asia|Africa|Pacific|IDA|IBRD|dividend|OECD|classified',
        case=False,
        na=False
    ))
][['Country Name', 'Country Code', '2023']].dropna()

# Sort
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

print(top10)

# Plot
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])
plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.tight_layout()
plt.show()
# Out:
#                                      Country Name Country Code          2023
# 109                                         India          IND  1.438070e+09
# 40                                          China          CHN  1.410710e+09
# 135  Least developed countries: UN classification          LDC  1.160825e+09
# 74       Fragile and conflict affected situations          FCS  1.058716e+09
# 98         Heavily indebted poor countries (HIPC)          HPC  9.173043e+08
# 134                     Latin America & Caribbean          LCN  6.576177e+08
# 170                                 North America          NAC  3.769544e+08
# 68                                      Euro area          EMU  3.502927e+08
# 251                                 United States          USA  3.368062e+08
# 106                                     Indonesia          IDN  2.811901e+08

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Load Dataset (IMPORTANT: tab separated)
df = pd.read_csv(r"C:\Users\Ravi Kant\Desktop\DS project\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv.csv",
   
    skiprows=4,
    sep='\t',
    engine='python'
)

# 2️⃣ Fix column names (remove tab & spaces)
df.columns = df.columns.str.replace('\t', '', regex=False)
df.columns = df.columns.str.strip()

# 3️⃣ Convert 2023 column to numeric
df['2023'] = pd.to_numeric(df['2023'], errors='coerce')

df_countries = df[
    (df['Indicator Name'] == 'Population, total') &
    (df['Country Code'].str.len() == 3) &
    (~df['Country Name'].str.contains(
        'World|income|IDA|IBRD|dividend|OECD|UN|classified|situations|states|area|Asia|Africa|Europe|America|Pacific',
        case=False,
        na=False
    ))
][['Country Name', '2023']].dropna()

# 5️⃣ Get Top 10 countries
top10 = df_countries.sort_values(by='2023', ascending=False).head(10)

# 6️⃣ Plot
plt.figure(figsize=(10,5))
plt.bar(top10['Country Name'], top10['2023'])

plt.xticks(rotation=45)
plt.title("Top 10 Countries by Population (2023)")
plt.xlabel("Country")
plt.ylabel("Population")

plt.tight_layout()
plt.show()

# %%
#HISTOGRAM:
plt.figure(figsize=(8,5))

plt.hist(df_countries['2023'], bins=20)

plt.title("Population Distribution Across Countries (2023)")
plt.xlabel("Population")
plt.ylabel("Number of Countries")

plt.tight_layout()
plt.show()
